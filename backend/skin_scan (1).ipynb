# %% [markdown]
# # **Skin Scan**

# %% [markdown]
# # **1. Background**

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Skin cancer is one of the most common types of cancer, and finding it early makes treatment much more effective. Doctors usually start with a basic visual exam, and if something looks concerning, they might use dermoscopy for a closer look, take a biopsy, and examine the tissue under a microscope. The challenge with automating this process is that skin lesions can be hard to distinguish. Lesions of the same type do not always look alike, and different types can appear very similar. Even experienced doctors sometimes have trouble classifying them, which is why machine learning could be a powerful tool for improving detection.

# %% [markdown]
# This project trains a machine learning model to
# classify skin lesions into seven categories:
#
# * **Actinic keratoses (akiec):** Precancerous lesions.
#
# * **Basal cell carcinoma (bcc):** A slow-growing skin cancer.
#
# * **Benign keratosis (bkl):** Non-cancerous growths.
#
# * **Dermatofibroma (df):** A harmless, firm nodule.
#
# * **Melanoma (mel):** A dangerous, fast-spreading cancer.
#
# * **Melanocytic nevi (nv):** Common moles, mostly benign.
#
# * **Vascular lesions (vasc):** Blood vessel abnormalities.

# %% [markdown]
# ## Dataset Overview

# %% [markdown]
# The **HAM10000** dataset, available on [Kaggle](https://www.kaggle.com/datasets/kmader/skin-cancer-mnist-ham10000), contains 10015 dermatoscopic images labeled across seven categories. It is publicly accessible through the ISIC archive and includes images from diverse sources, covering different lighting conditions, skin types, and imaging devices. This variety makes it a strong benchmark for developing machine learning models that can handle real-world variability in skin lesion classification.

# %% [markdown]
# ## Model Overview (CNN)

# %% [markdown]
# The **Convolutional Neural Network (CNN)** is a deep learning model designed to process image data, making it perfect for tasks like detecting skin cancer from images. The model works by detecting patterns and features in images through several key layers.
#
# <br>
#
# ![unnamed8PDPDZ_1_1ZBHFR.webp](data:image/webp;base64,...)

# %% [markdown]
# 1.   **Convolutional Layers:** Detect basic features like edges and textures by applying filters to small parts of the image.
#
# 2.   **ReLU Activation:** Removes negative values from the feature maps, keeping only useful information.
#
# 3.   **Pooling Layers:** Reduce the image size by focusing on the most important details (like using the max value in small sections).
#
# 4.   **Fully Connected Layers:** Flatten the data into a single list, then use it to make the final decision about the image.
#
# 5.   **Output Layer:** Gives a probability for each class (e.g., cancerous or not) using softmax or sigmoid.

# %% [markdown]
# #**2. Imports**

# %%
import numpy as np
import pandas as pd
import os
from glob import glob
from google.colab import drive
from PIL import Image
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, GlobalAveragePooling2D
from keras.regularizers import l2
from keras.optimizers import Adam, Adamax
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
drive.mount('/content/drive')

image_dir = '/content/drive/MyDrive/ML_Dataset'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **3. Data Preprocessing**

# %% [markdown]
# ## Reading Dataset Metadata

# %%
lesion_df = pd.read_csv(image_dir + '/metadata/HAM10000_metadata.csv')

# lesion_df.info()

# %% [markdown]
# ## Reading Lesion Images

# %%
# lesion_dict is a dictionary that displays more human friendly labels
lesion_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoseas',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
# imageid_path_dict is a dictionary that maps image id to the full path of the image
# it merges the 2 images directories into a single dictionary
imageid_path_dict = {
    os.path.splitext(os.path.basename(x))[0]: x
    for x in glob(os.path.join(image_dir + '/images', '*', '*.jpg'))
}

len(imageid_path_dict)
# Out:
# 10015

# %% [markdown]
# ## Feature Manipulataion & Set Up

# %% [markdown]
# **Creating new columns in the Dataframe for clearer Features**
# *   path column represents the file path to a given image
# *   lesion_type is the human friendly legion representation (done using the lesion_dict dictionary)
# *   lesion_type_id is the corresponding index in the lesion_dict

# %%
lesion_df['path'] = lesion_df['image_id'].map(imageid_path_dict.get)
lesion_df['lesion_type'] = lesion_df['dx'].map(lesion_dict.get)
lesion_df['lesion_type_id'] = pd.Categorical(lesion_df['lesion_type']).codes

# df.head()

# %%
lesion_df['image'] = lesion_df['path'].map(lambda image_path: np.asarray(Image.open(image_path).resize((100,75))))

# %% [markdown]
# # **4. Data Cleaning**

# %% [markdown]
# ## Removing NULL fields

# %% [markdown]
# Checking for missing/null datatype for each of the fields in the Dataset

# %%
lesion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lesion_id       10015 non-null  object
#  1   image_id        10015 non-null  object
#  2   dx              10015 non-null  object
#  3   dx_type         10015 non-null  object
#  4   age             9958 non-null   float64
#  5   sex             10015 non-null  object
#  6   localization    10015 non-null  object
#  7   path            10015 non-null  object
#  8   lesion_type     10015 non-null  object
#  9   lesion_type_id  10015 non-null  int8
#  10  image           10015 non-null  object
# dtypes: float64(1), int8(1), object(9)
# memory usage: 792.3+ KB

# %% [markdown]
# As we can see there are a total of 10015 records/entries
#
# Most columns are non-null to that exact number of 10015 except age with 9958/10015 records being non-null

# %%
lesion_df.isnull().sum()
# Out:
# lesion_id          0
# image_id           0
# dx                 0
# dx_type            0
# age               57
# sex                0
# localization       0
# path               0
# lesion_type        0
# lesion_type_id     0
# image              0
# dtype: int64

# %% [markdown]
# As shown above we can see that 57 records have age set to NULL
#
# We will replace these values with the mean of all existing ages in the Dataset

# %%
lesion_df['age'] = lesion_df['age'].fillna(lesion_df['age'].mean())

# %% [markdown]
# After checking again we can see that there are no more NULL values in the dataset

# %%
lesion_df.isnull().sum()
# Out:
# lesion_id         0
# image_id          0
# dx                0
# dx_type           0
# age               0
# sex               0
# localization      0
# path              0
# lesion_type       0
# lesion_type_id    0
# image             0
# dtype: int64

# %% [markdown]
# # **5. Exploratory Data Analysis (EDA)**

# %%
lesion_df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path  \
# 0  /content/drive/MyDrive/ML_Dataset/images/HAM10...
# 1  /content/drive/MyDrive/ML_Dataset/images/HAM10...
# 2  /content/drive/MyDrive/ML_Dataset/images/HAM10...
# 3  /content/drive/MyDrive/ML_Dataset/images/HAM10...
# 4  /content/drive/MyDrive/ML_Dataset/images/HAM10...
#
#                       lesion_type  lesion_type_id  \
# 0  Benign keratosis-like lesions                2
# 1  Benign keratosis-like lesions                2
# 2  Benign keratosis-like lesions                2
# 3  Benign keratosis-like lesions                2
# 4  Benign keratosis-like lesions                2
#
#                                                image
# 0  [[[190, 153, 194], [192, 154, 196], [191, 153,...
# 1  [[[23, 13, 22], [24, 14, 24], [25, 14, 28], [3...
# 2  [[[185, 127, 137], [189, 133, 147], [194, 136,...
# 3  [[[24, 11, 17], [26, 13, 22], [38, 21, 32], [5...
# 4  [[[134, 90, 113], [147, 102, 125], [159, 115, ...

# %% [markdown]
# ## Gender Distribution

# %%
counts = lesion_df.groupby('sex').size().sort_values(ascending=True)

ax = counts.plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
ax.set_title('Lesions Count by Sex')
ax.set_xlabel('Frequency')

plt.gca().spines[['top', 'right']].set_visible(False)

for p in ax.patches:
    ax.annotate(f'{p.get_width()}',
                (p.get_width() + 0.2, p.get_y() + p.get_height() / 2),
                ha='left', va='center')

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## Lesion Type Distribution

# %%
counts = lesion_df.groupby('lesion_type').size().sort_values(ascending=True)

ax = counts.plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
ax.set_title('Lesions Count by Type')
ax.set_xlabel('Frequency')

plt.gca().spines[['top', 'right']].set_visible(False)

for p in ax.patches:
    ax.annotate(f'{p.get_width()}',
                (p.get_width() + 0.2, p.get_y() + p.get_height() / 2),
                ha='left', va='center')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## Localization Distribution

# %%
counts = lesion_df.groupby('localization').size().sort_values(ascending=True)

ax = counts.plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
ax.set_title('Lesions Count by Localization')
plt.gca().spines[['top', 'right']].set_visible(False)

for p in ax.patches:
    ax.annotate(f'{p.get_width()}',
                (p.get_width() + 0.2, p.get_y() + p.get_height() / 2),
                ha='left', va='center')

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## Diagnosis Distribution

# %%
lesion_df['dx_type'].value_counts().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))

plt.title('Diagnosis Type Count', fontsize=12)
plt.xlabel('Frequency', fontsize=10)
plt.ylabel('Diagnosis Type', fontsize=10)

plt.gca().spines[['top', 'right']].set_visible(False)

plt.yticks(rotation=0, fontsize=8)
plt.xticks(fontsize=8)

plt.show()

# %% [markdown]
# ## Age Distribution

# %%
lesion_df['age'].value_counts().sort_values(ascending=True).plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))

plt.title('Age Distribution Count', fontsize=12)
plt.xlabel('Frequency', fontsize=10)
plt.ylabel('Age', fontsize=10)

plt.gca().spines[['top', 'right']].set_visible(False)

plt.yticks(rotation=0, fontsize=8)
plt.xticks(fontsize=8)

plt.show()

# %%
lesion_df['age'].plot(kind='hist', bins=20, color=sns.color_palette('Dark2')[0], rwidth=0.8)

plt.title('Age Distribution', fontsize=12)
plt.xlabel('Age', fontsize=10)
plt.ylabel('Frequency', fontsize=10)

plt.gca().spines[['top', 'right']].set_visible(False)

plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.show()

# %% [markdown]
# # **6. Data Model**

# %% [markdown]
# ## Features and Target Variables (Labels)

# %%
X = lesion_df.drop(columns=['lesion_type_id'],axis=1) # Features
y = lesion_df['lesion_type_id'] # Target

# %% [markdown]
# ## Data Split (Training & Test)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 11)

# %% [markdown]
# ## Image Normalization

# %% [markdown]
# **Z-score normalization**
# <br><br>
# $
# X_{\text{std}} = \frac{X - \mu}{\sigma}
# $
#
# - $X_{\text{std}}$ = standardized pixel value
# - $X$ = original pixel value
# - $μ$ = mean of all pixel values
# - $\sigma$ = standard deviation of all pixel values
#
# <br>

# %%
X_train_arr = np.asarray(X_train['image'].tolist())

X_train_mean = np.mean(X_train_arr)
X_train_std = np.std(X_train_arr)

X_train = (X_train_arr - X_train_mean) / X_train_std


X_test_arr = np.asarray(X_test['image'].tolist())
X_test_mean = np.mean(X_test_arr)
X_test_std = np.std(X_test_arr)

X_test = (X_test_arr - X_test_mean) / X_test_std

# %% [markdown]
# ## Label Encoding

# %% [markdown]
# **One-hot encoding** is a method used to convert categorical labels (like class labels) into a binary format
# * This makes it easier for our model handle processing the data

# %%
y_train = to_categorical(y_train, num_classes = 7)
y_test = to_categorical(y_test, num_classes = 7)

# %% [markdown]
# ## Data Split (Validation & Testing)

# %%
X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train, test_size = 0.1, random_state = 22)

# %%
# Reshape image in 3 dimensions (height = 75px, width = 100px , canal = 3)
X_train = X_train.reshape(X_train.shape[0], *(75, 100, 3))
X_test = X_test.reshape(X_test.shape[0], *(75, 100, 3))

# %% [markdown]
# ## CNN Model

# %% [markdown]
# ###Model Structure

# %%
# input_shape = (75, 100, 3)
# num_classes = 7

# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',padding = 'Same',input_shape=input_shape))
# model.add(Conv2D(32,kernel_size=(3, 3), activation='relu',padding = 'Same',))
# model.add(MaxPool2D(pool_size = (2, 2)))
# model.add(Dropout(0.25))

# model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
# model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
# model.add(MaxPool2D(pool_size=(2, 2)))
# model.add(Dropout(0.40))

# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(num_classes, activation='softmax'))
# model.summary()

input_shape = (75, 100, 3)
num_classes = 7

model = Sequential()

# Feature Extraction
model.add(Conv2D(32, (3, 3), activation='relu', padding='Same', input_shape=input_shape, kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu', padding='Same', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu', padding='Same', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu', padding='Same', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.4))

# Classifier
model.add(GlobalAveragePooling2D())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(num_classes, activation='softmax'))

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 75, 100, 32)         │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 75, 100, 32)         │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 75, 100, 32)         │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 75, 100, 32)         │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 37, 50, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 37, 50, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 37, 50, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 37, 50, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 37, 50, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 37, 50, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 18, 25, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 18, 25, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 64)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 75,559 (295.15 KB)
#  Trainable params: 75,175 (293.65 KB)
#  Non-trainable params: 384 (1.50 KB)

# %% [markdown]
# <br>
#
# ###Optimizer Configuration and Model Checkpointing

# %% [markdown]
# This code sets up the optimizer, compiles the model, and defines a checkpoint to save the best model during training.
# * **Adam Optimizer** – A smart optimizer that automatically adjusts how much the model’s weights change during training, so the model can learn more efficiently.
# * **Categorical Cross-Entropy Loss** – A way to measure how far off the model’s predictions are from the actual labels when you’re working with multiple classes.
# * **Model Checkpoint** – A feature that saves the model whenever it performs the best on the validation data, so you can keep the best version and avoid overfitting.

# %%
# Define the optimizer (Adam is an adaptive learning rate optimization algorithm)
optimizer = Adam(learning_rate=0.001)  # Learning rate controls how much weights update during training

# Compile the model with loss function and evaluation metric
model.compile(
    optimizer=optimizer,                # Optimizer responsible for adjusting model weights
    loss="categorical_crossentropy",    # Loss function for multi-class classification
    metrics=["accuracy"]                # Track accuracy during training
)

# Define a checkpoint to save the best model
learning_rate_reduction = ModelCheckpoint(
    filepath='best_model.h5',  # Filepath to save the best model weights
    monitor='val_acc',         # Monitor validation accuracy to determine the best model
    mode='max',                # Save the model when validation accuracy is at its highest
    verbose=1,                 # Print updates when a new best model is saved
    save_best_only=True        # Only save models that improve performance
)

# %% [markdown]
# <br>
#
# ###Data Augmentation

# %% [markdown]
# **ImageDataGenerator** is a tool for data augmentation that slightly alters images during training. It applies random rotations, zooming, and shifts to introduce variation, helping the model generalize better and avoid overfitting. By making small, random changes to the images, the model learns patterns instead of memorizing specific images, improving its ability to classify new data.

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,             # Don't normalize based on the dataset mean (no feature-wise centering)
        samplewise_center=False,              # Don't normalize each image individually (no sample-wise centering)
        featurewise_std_normalization=False,  # No standard deviation normalization for the dataset (no feature-wise std normalization)
        samplewise_std_normalization=False,   # No standard deviation normalization per image (no sample-wise std normalization)
        zca_whitening=False,                  # No ZCA whitening applied (no decorrelation of pixel values)
        rotation_range=10,                    # Rotate images randomly by up to 10 degrees (data augmentation)
        zoom_range=0.1,                       # Apply random zooming up to 10% (data augmentation)
        width_shift_range=0.1,                # Shift images horizontally by up to 10% (data augmentation)
        height_shift_range=0.1,               # Shift images vertically by up to 10% (data augmentation)
        horizontal_flip=False,                # No horizontal flipping (no left-right mirroring)
        vertical_flip=False)                  # No vertical flipping (no upside-down mirroring)

# Computes any necessary statistics from training data
datagen.fit(X_train)

# %% [markdown]
# <br>
#
# ###Training Model

# %%
epochs = 150     # Number of times the model will go through the entire dataset
batch_size = 60  # Number of samples per training step

# Fit the model with the augmented data and training settings
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=batch_size),  # Flow method generates batches of augmented images
    epochs=epochs,                                          # Train for the specified number of epochs
    validation_data=(X_validate, y_validate),               # Use validation data for evaluating the model after each epoch
    verbose=1,                                              # Print progress during training (1 means show a progress bar)
    steps_per_epoch=X_train.shape[0] // batch_size,         # Number of steps per epoch (total samples divided by batch size)
    callbacks=[learning_rate_reduction]                     # Apply the learning rate reduction callback to save the best model
)
# Out:
# Epoch 1/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 380s 3s/step - accuracy: 0.6931 - loss: 0.9147 - val_accuracy: 0.7357 - val_loss: 0.8365
# Epoch 2/150
#   1/120 ━━━━━━━━━━━━━━━━━━━━ 5:07 3s/step - accuracy: 0.7000 - loss: 0.8921
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7000 - loss: 0.8921 - val_accuracy: 0.7357 - val_loss: 0.8371
# Epoch 3/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.7002 - loss: 0.8892 - val_accuracy: 0.7369 - val_loss: 0.8114
# Epoch 4/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7333 - loss: 0.8663 - val_accuracy: 0.7382 - val_loss: 0.8130
# Epoch 5/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 360s 3s/step - accuracy: 0.7029 - loss: 0.8796 - val_accuracy: 0.7257 - val_loss: 0.7938
# Epoch 6/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6333 - loss: 0.8926 - val_accuracy: 0.7307 - val_loss: 0.7965
# Epoch 7/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 360s 3s/step - accuracy: 0.6962 - loss: 0.8857 - val_accuracy: 0.7344 - val_loss: 0.7960
# Epoch 8/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6167 - loss: 0.9852 - val_accuracy: 0.7369 - val_loss: 0.8016
# Epoch 9/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.7042 - loss: 0.8585 - val_accuracy: 0.7319 - val_loss: 0.7845
# Epoch 10/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.7500 - loss: 0.8103 - val_accuracy: 0.7294 - val_loss: 0.7821
# Epoch 11/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 361s 3s/step - accuracy: 0.7104 - loss: 0.8372 - val_accuracy: 0.7195 - val_loss: 0.7884
# Epoch 12/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7000 - loss: 0.7528 - val_accuracy: 0.7219 - val_loss: 0.7896
# Epoch 13/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 361s 3s/step - accuracy: 0.7079 - loss: 0.8153 - val_accuracy: 0.7282 - val_loss: 0.7505
# Epoch 14/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7167 - loss: 0.7834 - val_accuracy: 0.7357 - val_loss: 0.7469
# Epoch 15/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 345s 3s/step - accuracy: 0.7176 - loss: 0.8000 - val_accuracy: 0.7344 - val_loss: 0.7428
# Epoch 16/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6500 - loss: 0.9204 - val_accuracy: 0.7282 - val_loss: 0.7453
# Epoch 17/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 383s 3s/step - accuracy: 0.7167 - loss: 0.8147 - val_accuracy: 0.7406 - val_loss: 0.7307
# Epoch 18/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7000 - loss: 0.8850 - val_accuracy: 0.7406 - val_loss: 0.7328
# Epoch 19/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.7232 - loss: 0.7856 - val_accuracy: 0.7244 - val_loss: 0.7276
# Epoch 20/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7167 - loss: 0.7589 - val_accuracy: 0.7244 - val_loss: 0.7215
# Epoch 21/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 359s 3s/step - accuracy: 0.7162 - loss: 0.7937 - val_accuracy: 0.7556 - val_loss: 0.7077
# Epoch 22/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7167 - loss: 0.8862 - val_accuracy: 0.7519 - val_loss: 0.7079
# Epoch 23/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 346s 3s/step - accuracy: 0.7210 - loss: 0.7803 - val_accuracy: 0.7444 - val_loss: 0.7355
# Epoch 24/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6333 - loss: 0.9585 - val_accuracy: 0.7431 - val_loss: 0.7339
# Epoch 25/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 358s 3s/step - accuracy: 0.7209 - loss: 0.7689 - val_accuracy: 0.7656 - val_loss: 0.7167
# Epoch 26/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7333 - loss: 0.7956 - val_accuracy: 0.7656 - val_loss: 0.7155
# Epoch 27/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.7278 - loss: 0.7565 - val_accuracy: 0.7469 - val_loss: 0.7119
# Epoch 28/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8000 - loss: 0.6504 - val_accuracy: 0.7456 - val_loss: 0.7161
# Epoch 29/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 353s 3s/step - accuracy: 0.7257 - loss: 0.7455 - val_accuracy: 0.7394 - val_loss: 0.7477
# Epoch 30/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.6500 - loss: 0.9391 - val_accuracy: 0.7419 - val_loss: 0.7487
# Epoch 31/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 340s 3s/step - accuracy: 0.7239 - loss: 0.7625 - val_accuracy: 0.7618 - val_loss: 0.6836
# Epoch 32/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7667 - loss: 0.7651 - val_accuracy: 0.7606 - val_loss: 0.6834
# Epoch 33/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.7337 - loss: 0.7529 - val_accuracy: 0.7569 - val_loss: 0.6833
# Epoch 34/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.7500 - loss: 0.7140 - val_accuracy: 0.7581 - val_loss: 0.6799
# Epoch 35/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.7349 - loss: 0.7316 - val_accuracy: 0.7469 - val_loss: 0.6931
# Epoch 36/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8333 - loss: 0.5474 - val_accuracy: 0.7506 - val_loss: 0.6868
# Epoch 37/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.7425 - loss: 0.7203 - val_accuracy: 0.7581 - val_loss: 0.6896
# Epoch 38/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8167 - loss: 0.5906 - val_accuracy: 0.7556 - val_loss: 0.6855
# Epoch 39/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 355s 3s/step - accuracy: 0.7416 - loss: 0.7139 - val_accuracy: 0.7618 - val_loss: 0.6743
# Epoch 40/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.6667 - loss: 0.8421 - val_accuracy: 0.7606 - val_loss: 0.6722
# Epoch 41/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 362s 3s/step - accuracy: 0.7379 - loss: 0.7157 - val_accuracy: 0.7419 - val_loss: 0.6906
# Epoch 42/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7667 - loss: 0.6328 - val_accuracy: 0.7294 - val_loss: 0.6989
# Epoch 43/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.7413 - loss: 0.7129 - val_accuracy: 0.7681 - val_loss: 0.6603
# Epoch 44/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7833 - loss: 0.6609 - val_accuracy: 0.7681 - val_loss: 0.6637
# Epoch 45/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 358s 3s/step - accuracy: 0.7362 - loss: 0.7284 - val_accuracy: 0.7693 - val_loss: 0.6581
# Epoch 46/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7333 - loss: 0.7352 - val_accuracy: 0.7681 - val_loss: 0.6530
# Epoch 47/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 362s 3s/step - accuracy: 0.7474 - loss: 0.7152 - val_accuracy: 0.7681 - val_loss: 0.6417
# Epoch 48/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7500 - loss: 0.6831 - val_accuracy: 0.7656 - val_loss: 0.6369
# Epoch 49/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.7338 - loss: 0.7319 - val_accuracy: 0.7668 - val_loss: 0.6707
# Epoch 50/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7000 - loss: 0.7411 - val_accuracy: 0.7606 - val_loss: 0.6788
# Epoch 51/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.7453 - loss: 0.7152 - val_accuracy: 0.7544 - val_loss: 0.6751
# Epoch 52/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.6833 - loss: 0.7473 - val_accuracy: 0.7544 - val_loss: 0.6776
# Epoch 53/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 361s 3s/step - accuracy: 0.7602 - loss: 0.6836 - val_accuracy: 0.7681 - val_loss: 0.6587
# Epoch 54/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.7833 - loss: 0.5784 - val_accuracy: 0.7668 - val_loss: 0.6604
# Epoch 55/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.7498 - loss: 0.6959 - val_accuracy: 0.7743 - val_loss: 0.6445
# Epoch 56/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.7000 - loss: 0.7469 - val_accuracy: 0.7756 - val_loss: 0.6414
# Epoch 57/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 356s 3s/step - accuracy: 0.7569 - loss: 0.6879 - val_accuracy: 0.7431 - val_loss: 0.7405
# Epoch 58/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 59ms/step - accuracy: 0.6167 - loss: 1.0066 - val_accuracy: 0.7394 - val_loss: 0.7478
# Epoch 59/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.7581 - loss: 0.6884 - val_accuracy: 0.7481 - val_loss: 0.7503
# Epoch 60/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7333 - loss: 0.7295 - val_accuracy: 0.7606 - val_loss: 0.7313
# Epoch 61/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 362s 3s/step - accuracy: 0.7500 - loss: 0.7001 - val_accuracy: 0.7481 - val_loss: 0.6948
# Epoch 62/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7833 - loss: 0.6467 - val_accuracy: 0.7469 - val_loss: 0.6901
# Epoch 63/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.7525 - loss: 0.6851 - val_accuracy: 0.7805 - val_loss: 0.6615
# Epoch 64/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7167 - loss: 0.7237 - val_accuracy: 0.7756 - val_loss: 0.6604
# Epoch 65/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - accuracy: 0.7645 - loss: 0.6867 - val_accuracy: 0.7494 - val_loss: 0.6790
# Epoch 66/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.7167 - loss: 0.8228 - val_accuracy: 0.7556 - val_loss: 0.6690
# Epoch 67/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.7576 - loss: 0.6740 - val_accuracy: 0.7569 - val_loss: 0.7502
# Epoch 68/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.7333 - loss: 0.9161 - val_accuracy: 0.7606 - val_loss: 0.7469
# Epoch 69/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.7517 - loss: 0.6961 - val_accuracy: 0.7369 - val_loss: 0.7180
# Epoch 70/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7000 - loss: 0.7301 - val_accuracy: 0.7294 - val_loss: 0.7288
# Epoch 71/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.7654 - loss: 0.6651 - val_accuracy: 0.7718 - val_loss: 0.6530
# Epoch 72/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - accuracy: 0.8167 - loss: 0.7134 - val_accuracy: 0.7706 - val_loss: 0.6542
# Epoch 73/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 357s 3s/step - accuracy: 0.7517 - loss: 0.6905 - val_accuracy: 0.7244 - val_loss: 0.7206
# Epoch 74/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8000 - loss: 0.6349 - val_accuracy: 0.7282 - val_loss: 0.7256
# Epoch 75/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.7639 - loss: 0.6483 - val_accuracy: 0.7756 - val_loss: 0.7054
# Epoch 76/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7667 - loss: 0.7252 - val_accuracy: 0.7768 - val_loss: 0.6982
# Epoch 77/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 421s 3s/step - accuracy: 0.7716 - loss: 0.6523 - val_accuracy: 0.7668 - val_loss: 0.6570
# Epoch 78/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7667 - loss: 0.6980 - val_accuracy: 0.7656 - val_loss: 0.6549
# Epoch 79/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 361s 3s/step - accuracy: 0.7633 - loss: 0.6615 - val_accuracy: 0.7793 - val_loss: 0.6761
# Epoch 80/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8000 - loss: 0.5449 - val_accuracy: 0.7818 - val_loss: 0.6624
# Epoch 81/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 373s 3s/step - accuracy: 0.7674 - loss: 0.6691 - val_accuracy: 0.7706 - val_loss: 0.6619
# Epoch 82/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8000 - loss: 0.6380 - val_accuracy: 0.7718 - val_loss: 0.6639
# Epoch 83/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.7625 - loss: 0.6647 - val_accuracy: 0.7469 - val_loss: 0.7391
# Epoch 84/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - accuracy: 0.7833 - loss: 0.6360 - val_accuracy: 0.7444 - val_loss: 0.7533
# Epoch 85/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 364s 3s/step - accuracy: 0.7816 - loss: 0.6377 - val_accuracy: 0.7519 - val_loss: 0.7247
# Epoch 86/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6333 - loss: 0.7915 - val_accuracy: 0.7494 - val_loss: 0.7189
# Epoch 87/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 359s 3s/step - accuracy: 0.7692 - loss: 0.6598 - val_accuracy: 0.7731 - val_loss: 0.6618
# Epoch 88/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7500 - loss: 0.8362 - val_accuracy: 0.7594 - val_loss: 0.6717
# Epoch 89/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 377s 3s/step - accuracy: 0.7777 - loss: 0.6468 - val_accuracy: 0.7818 - val_loss: 0.6170
# Epoch 90/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8167 - loss: 0.6004 - val_accuracy: 0.7793 - val_loss: 0.6162
# Epoch 91/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 362s 3s/step - accuracy: 0.7739 - loss: 0.6500 - val_accuracy: 0.7631 - val_loss: 0.6818
# Epoch 92/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.6167 - loss: 0.9121 - val_accuracy: 0.7606 - val_loss: 0.6994
# Epoch 93/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 352s 3s/step - accuracy: 0.7742 - loss: 0.6472 - val_accuracy: 0.7805 - val_loss: 0.6517
# Epoch 94/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.8667 - loss: 0.4925 - val_accuracy: 0.7718 - val_loss: 0.6750
# Epoch 95/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 363s 3s/step - accuracy: 0.7559 - loss: 0.6909 - val_accuracy: 0.7631 - val_loss: 0.6991
# Epoch 96/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8000 - loss: 0.6068 - val_accuracy: 0.7643 - val_loss: 0.6988
# Epoch 97/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.7659 - loss: 0.6522 - val_accuracy: 0.7843 - val_loss: 0.6594
# Epoch 98/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8500 - loss: 0.4696 - val_accuracy: 0.7855 - val_loss: 0.6617
# Epoch 99/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 361s 3s/step - accuracy: 0.7747 - loss: 0.6443 - val_accuracy: 0.7768 - val_loss: 0.6420
# Epoch 100/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8000 - loss: 0.5514 - val_accuracy: 0.7731 - val_loss: 0.6522
# Epoch 101/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 373s 3s/step - accuracy: 0.7822 - loss: 0.6394 - val_accuracy: 0.7606 - val_loss: 0.7033
# Epoch 102/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7667 - loss: 0.6459 - val_accuracy: 0.7569 - val_loss: 0.6961
# Epoch 103/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.7782 - loss: 0.6368 - val_accuracy: 0.7731 - val_loss: 0.6362
# Epoch 104/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8667 - loss: 0.5796 - val_accuracy: 0.7768 - val_loss: 0.6392
# Epoch 105/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 362s 3s/step - accuracy: 0.7797 - loss: 0.6236 - val_accuracy: 0.7294 - val_loss: 0.7637
# Epoch 106/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8333 - loss: 0.5076 - val_accuracy: 0.7132 - val_loss: 0.7910
# Epoch 107/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.7746 - loss: 0.6556 - val_accuracy: 0.7855 - val_loss: 0.6338
# Epoch 108/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.7833 - loss: 0.5107 - val_accuracy: 0.7868 - val_loss: 0.6361
# Epoch 109/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 352s 3s/step - accuracy: 0.7687 - loss: 0.6563 - val_accuracy: 0.7743 - val_loss: 0.6467
# Epoch 110/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8333 - loss: 0.5935 - val_accuracy: 0.7643 - val_loss: 0.6566
# Epoch 111/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.7887 - loss: 0.6102 - val_accuracy: 0.7631 - val_loss: 0.6897
# Epoch 112/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.7333 - loss: 0.6813 - val_accuracy: 0.7606 - val_loss: 0.7014
# Epoch 113/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 390s 3s/step - accuracy: 0.7727 - loss: 0.6470 - val_accuracy: 0.7581 - val_loss: 0.7049
# Epoch 114/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7667 - loss: 0.7366 - val_accuracy: 0.7506 - val_loss: 0.7115
# Epoch 115/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.7890 - loss: 0.6225 - val_accuracy: 0.7756 - val_loss: 0.6330
# Epoch 116/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8000 - loss: 0.6109 - val_accuracy: 0.7756 - val_loss: 0.6460
# Epoch 117/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 358s 3s/step - accuracy: 0.7739 - loss: 0.6337 - val_accuracy: 0.7618 - val_loss: 0.6685
# Epoch 118/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7500 - loss: 0.7672 - val_accuracy: 0.7706 - val_loss: 0.6600
# Epoch 119/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 360s 3s/step - accuracy: 0.7888 - loss: 0.6145 - val_accuracy: 0.7768 - val_loss: 0.6665
# Epoch 120/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7000 - loss: 0.7584 - val_accuracy: 0.7743 - val_loss: 0.6589
# Epoch 121/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 357s 3s/step - accuracy: 0.7787 - loss: 0.6281 - val_accuracy: 0.7880 - val_loss: 0.6479
# Epoch 122/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8333 - loss: 0.5047 - val_accuracy: 0.7781 - val_loss: 0.6495
# Epoch 123/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 363s 3s/step - accuracy: 0.7872 - loss: 0.6261 - val_accuracy: 0.7668 - val_loss: 0.6402
# Epoch 124/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8667 - loss: 0.4571 - val_accuracy: 0.7643 - val_loss: 0.6448
# Epoch 125/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 360s 3s/step - accuracy: 0.7876 - loss: 0.6105 - val_accuracy: 0.7781 - val_loss: 0.6694
# Epoch 126/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7000 - loss: 0.8066 - val_accuracy: 0.7793 - val_loss: 0.6656
# Epoch 127/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.7905 - loss: 0.6156 - val_accuracy: 0.7506 - val_loss: 0.7318
# Epoch 128/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8500 - loss: 0.6113 - val_accuracy: 0.7431 - val_loss: 0.7431
# Epoch 129/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 362s 3s/step - accuracy: 0.7815 - loss: 0.6168 - val_accuracy: 0.7818 - val_loss: 0.7042
# Epoch 130/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7167 - loss: 0.7783 - val_accuracy: 0.7818 - val_loss: 0.6919
# Epoch 131/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.7922 - loss: 0.6053 - val_accuracy: 0.7357 - val_loss: 0.8018
# Epoch 132/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7500 - loss: 0.5786 - val_accuracy: 0.7394 - val_loss: 0.7911
# Epoch 133/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 360s 3s/step - accuracy: 0.7982 - loss: 0.5826 - val_accuracy: 0.7419 - val_loss: 0.7369
# Epoch 134/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8167 - loss: 0.6222 - val_accuracy: 0.7444 - val_loss: 0.7213
# Epoch 135/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.7876 - loss: 0.6315 - val_accuracy: 0.7955 - val_loss: 0.6347
# Epoch 136/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.7833 - loss: 0.6909 - val_accuracy: 0.7905 - val_loss: 0.6232
# Epoch 137/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.7895 - loss: 0.6026 - val_accuracy: 0.7855 - val_loss: 0.6492
# Epoch 138/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 9s 52ms/step - accuracy: 0.8333 - loss: 0.5151 - val_accuracy: 0.7805 - val_loss: 0.6480
# Epoch 139/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.7859 - loss: 0.6055 - val_accuracy: 0.7618 - val_loss: 0.6880
# Epoch 140/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.6667 - loss: 0.8355 - val_accuracy: 0.7618 - val_loss: 0.6900
# Epoch 141/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 360s 3s/step - accuracy: 0.7876 - loss: 0.6065 - val_accuracy: 0.7768 - val_loss: 0.6678
# Epoch 142/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8333 - loss: 0.5970 - val_accuracy: 0.7768 - val_loss: 0.6685
# Epoch 143/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 358s 3s/step - accuracy: 0.7913 - loss: 0.6082 - val_accuracy: 0.7494 - val_loss: 0.7139
# Epoch 144/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8167 - loss: 0.4317 - val_accuracy: 0.7469 - val_loss: 0.7248
# Epoch 145/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 359s 3s/step - accuracy: 0.7936 - loss: 0.6048 - val_accuracy: 0.7818 - val_loss: 0.6284
# Epoch 146/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 13s 86ms/step - accuracy: 0.8000 - loss: 0.6262 - val_accuracy: 0.7793 - val_loss: 0.6314
# Epoch 147/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 364s 3s/step - accuracy: 0.7897 - loss: 0.6146 - val_accuracy: 0.7768 - val_loss: 0.7044
# Epoch 148/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.7000 - loss: 0.7874 - val_accuracy: 0.7781 - val_loss: 0.6975
# Epoch 149/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 349s 3s/step - accuracy: 0.8018 - loss: 0.5907 - val_accuracy: 0.7681 - val_loss: 0.6977
# Epoch 150/150
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.8500 - loss: 0.4851 - val_accuracy: 0.7693 - val_loss: 0.7076

# %% [markdown]
# <br>
#
# ###Model Accurary Plot

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.show()

# %% [markdown]
# <br>
#
# ###Model Loss Plot

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.show()

# %%
model.save("skin_scan_model.keras")
